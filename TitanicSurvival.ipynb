# %% [markdown]
# # Titanic Survival Part 2: Machine Learning Predictions in Python

# %%
# import modules
import numpy as np 
import pandas as pd 
import os

# load train dataset 
train = pd.read_csv("../input/train.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ## Name:
#
#  1. Extract titles with regex
#  2. create Title attribute
#  3. Extract number of characters
#  4. create NameLength
#  5. drop Name
#
#  * NB: keep `PassengerID`, will need it for the competition submission file.

# %%
import re 

pattern = r',\s(.+?)\.'

# %%
def extract_title(a_name):
    """Given a name from the Name column, extract the title by searching for the pattern, 
       returning a tuple that identifies whether the regex worked or not.
    """
    try:
        return (True, *tuple(re.search(pattern, a_name).groups()))
    except:
        return (False, a_name)
    
# testing the function
name_entry = train['Name'][1]
name_entry
extract_title(name_entry)
# Out:
# (True, 'Mrs')

# %%
# testing whether all names can be parsed successfully
parsed_name = train['Name'].map(lambda x: extract_title(x))

# %%
parsed_name.head()
# Out:
# 0      (True, Mr)
# 1     (True, Mrs)
# 2    (True, Miss)
# 3     (True, Mrs)
# 4      (True, Mr)
# Name: Name, dtype: object

# %%
def sum_line(line):
    ct = 0
    if line[0] == True:
        ct += 1
    return ct

passed = parsed_name.map(lambda x: sum_line(x))

# %%
sum(passed) == len(parsed_name)
# Out:
# True

# %%
# unpack tuples to get titles
def unpack_tuples(x):
    a,b = x
    return b

titles = parsed_name.map(lambda x: unpack_tuples(x))

# %%
titles.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
all_titles = titles.unique().tolist()
common_titles = ["Mr", "Mrs", "Miss"]
#rare_titles = list(set(all_titles) - set(common_titles))

# %%
def simplify_title(x):
    """"Given a parsed name, extract the title from the tuple, 
       if it belongs to a common title, return that, otherwise, return 'rare'
    """
    try:
        a,b = x
        if b in common_titles:
            return (b)
        else:
            return ('Rare')
    except:
        return ('')

parsed_name_clean = parsed_name.map(lambda x: simplify_title(x))

# %% [markdown]
# ## Name Length

# %%
train['NameLength'] = train['Name'].map(lambda x: len(x))

# %%
#pd.options.display.max_rows = 400

data={'original': train['Name'], 'parsed':parsed_name, 'clean':parsed_name_clean, 'length': train['NameLength']}
pd.DataFrame(data).head(10)
# Out:
#                                             original          parsed clean  \
# 0                            Braund, Mr. Owen Harris      (True, Mr)    Mr
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...     (True, Mrs)   Mrs
# 2                             Heikkinen, Miss. Laina    (True, Miss)  Miss
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)     (True, Mrs)   Mrs
# 4                           Allen, Mr. William Henry      (True, Mr)    Mr
# 5                                   Moran, Mr. James      (True, Mr)    Mr
# 6                            McCarthy, Mr. Timothy J      (True, Mr)    Mr
# 7                     Palsson, Master. Gosta Leonard  (True, Master)  Rare
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     (True, Mrs)   Mrs
# 9                Nasser, Mrs. Nicholas (Adele Achem)     (True, Mrs)   Mrs
#
#    length
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
# 5      16
# 6      23
# 7      30
# 8      49
# 9      35

# %%
train['Title'] = parsed_name_clean

# %%
# drop Name variable
train = train.drop('Name', 1)

# %%
# current state of our train dataset
train.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
# 5            6         0       3    male   NaN      0      0
# 6            7         0       1    male  54.0      0      0
# 7            8         0       3    male   2.0      3      1
# 8            9         1       3  female  27.0      0      2
# 9           10         1       2  female  14.0      1      0
#
#              Ticket     Fare Cabin Embarked  NameLength Title
# 0         A/5 21171   7.2500   NaN        S          23    Mr
# 1          PC 17599  71.2833   C85        C          51   Mrs
# 2  STON/O2. 3101282   7.9250   NaN        S          22  Miss
# 3            113803  53.1000  C123        S          44   Mrs
# 4            373450   8.0500   NaN        S          24    Mr
# 5            330877   8.4583   NaN        Q          16    Mr
# 6             17463  51.8625   E46        S          23    Mr
# 7            349909  21.0750   NaN        S          30  Rare
# 8            347742  11.1333   NaN        S          49   Mrs
# 9            237736  30.0708   NaN        C          35   Mrs

# %% [markdown]
# ## Sex, SibSp & Parch

# %%
def is_male(x):
    try:
        if x == 'male':
            return(1)
        else:
            return(0)
    except:
        pass
    
train['IsMale'] = train['Sex'].map(lambda x: is_male(x))

# %%
train = train.drop('Sex', 1)

# %%
train['NumRelatives'] = train['SibSp'] + train['Parch']

# %%
train = train.drop('SibSp', 1)
train = train.drop('Parch', 1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age            Ticket     Fare Cabin  \
# 0            1         0       3  22.0         A/5 21171   7.2500   NaN
# 1            2         1       1  38.0          PC 17599  71.2833   C85
# 2            3         1       3  26.0  STON/O2. 3101282   7.9250   NaN
# 3            4         1       1  35.0            113803  53.1000  C123
# 4            5         0       3  35.0            373450   8.0500   NaN
#
#   Embarked  NameLength Title  IsMale  NumRelatives
# 0        S          23    Mr       1             1
# 1        C          51   Mrs       0             1
# 2        S          22  Miss       0             0
# 3        S          44   Mrs       0             1
# 4        S          24    Mr       1             0

# %% [markdown]
# ## Ticket & Fare

# %%
train['count'] = 1

# %%
group = train[['Ticket','Fare','count']].groupby('Ticket').sum() # just didn't work, the Fare should stay the same

# %%
group['Fare'] = group['Fare']/group['count']
group['FarePerPerson'] = (group['Fare'])/group['count']

# %%
group.head()
# Out:
#          Fare  count  FarePerPerson
# Ticket
# 110152  86.50      3      28.833333
# 110413  79.65      3      26.550000
# 110465  52.00      2      26.000000
# 110564  26.55      1      26.550000
# 110813  75.25      1      75.250000

# %%
# testing
sort_by_ticket = train.sort_values('Ticket')
sort_by_ticket.head(10)
# Out:
#      PassengerId  Survived  Pclass   Age  Ticket   Fare Cabin Embarked  \
# 504          505         1       1  16.0  110152  86.50   B79        S
# 257          258         1       1  30.0  110152  86.50   B77        S
# 759          760         1       1  33.0  110152  86.50   B77        S
# 262          263         0       1  52.0  110413  79.65   E67        S
# 558          559         1       1  39.0  110413  79.65   E67        S
# 585          586         1       1  18.0  110413  79.65   E68        S
# 110          111         0       1  47.0  110465  52.00  C110        S
# 475          476         0       1   NaN  110465  52.00   A14        S
# 430          431         1       1  28.0  110564  26.55   C52        S
# 366          367         1       1  60.0  110813  75.25   D37        C
#
#      NameLength Title  IsMale  NumRelatives  count
# 504          21  Miss       0             0      1
# 257          20  Miss       0             0      1
# 759          56  Rare       0             0      1
# 262          17    Mr       1             2      1
# 558          38   Mrs       0             2      1
# 585          19  Miss       0             2      1
# 110          30    Mr       1             0      1
# 475          27    Mr       1             0      1
# 430          41    Mr       1             0      1
# 366          48   Mrs       0             1      1

# %%
def map_fare_perperson(a_ticket):

    row_names=list(group.index.values)
    row_names_array=np.array(row_names)
    loc=np.where(row_names_array == a_ticket)[0][0]
    return(group['FarePerPerson'][loc:loc+1][0])
    
sort_by_ticket['FarePerPerson'] = sort_by_ticket['Ticket'].map(lambda x: map_fare_perperson(x))
sort_by_ticket.head(20)
# Out:
#      PassengerId  Survived  Pclass   Age  Ticket     Fare Cabin Embarked  \
# 504          505         1       1  16.0  110152  86.5000   B79        S
# 257          258         1       1  30.0  110152  86.5000   B77        S
# 759          760         1       1  33.0  110152  86.5000   B77        S
# 262          263         0       1  52.0  110413  79.6500   E67        S
# 558          559         1       1  39.0  110413  79.6500   E67        S
# 585          586         1       1  18.0  110413  79.6500   E68        S
# 110          111         0       1  47.0  110465  52.0000  C110        S
# 475          476         0       1   NaN  110465  52.0000   A14        S
# 430          431         1       1  28.0  110564  26.5500   C52        S
# 366          367         1       1  60.0  110813  75.2500   D37        C
# 170          171         0       1  61.0  111240  33.5000   B19        S
# 462          463         0       1  47.0  111320  38.5000   E63        S
# 523          524         1       1  44.0  111361  57.9792   B18        C
# 329          330         1       1  16.0  111361  57.9792   B18        C
# 889          890         1       1  26.0  111369  30.0000  C148        C
# 604          605         1       1  35.0  111426  26.5500   NaN        C
# 507          508         1       1   NaN  111427  26.5500   NaN        S
# 187          188         1       1  45.0  111428  26.5500   NaN        S
# 806          807         0       1  39.0  112050   0.0000   A36        S
# 633          634         0       1   NaN  112052   0.0000   NaN        S
#
#      NameLength Title  IsMale  NumRelatives  count  FarePerPerson
# 504          21  Miss       0             0      1      28.833333
# 257          20  Miss       0             0      1      28.833333
# 759          56  Rare       0             0      1      28.833333
# 262          17    Mr       1             2      1      26.550000
# 558          38   Mrs       0             2      1      26.550000
# 585          19  Miss       0             2      1      26.550000
# 110          30    Mr       1             0      1      26.000000
# 475          27    Mr       1             0      1      26.000000
# 430          41    Mr       1             0      1      26.550000
# 366          48   Mrs       0             1      1      75.250000
# 170          25    Mr       1             0      1      33.500000
# 462          17    Mr       1             0      1      38.500000
# 523          47   Mrs       0             1      1      28.989600
# 329          28  Miss       0             1      1      28.989600
# 889          21    Mr       1             0      1      30.000000
# 604          31    Mr       1             0      1      26.550000
# 507          45    Mr       1             0      1      26.550000
# 187          45    Mr       1             0      1      26.550000
# 806          22    Mr       1             0      1       0.000000
# 633          29    Mr       1             0      1       0.000000

# %%
train['FarePerPerson'] = train['Ticket'].map(lambda x: map_fare_perperson(x))

# %%
train = train.drop('Ticket', 1)
train = train.drop('Fare', 1)
train = train.drop('count', 1)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age Cabin Embarked  NameLength Title  \
# 0            1         0       3  22.0   NaN        S          23    Mr
# 1            2         1       1  38.0   C85        C          51   Mrs
# 2            3         1       3  26.0   NaN        S          22  Miss
# 3            4         1       1  35.0  C123        S          44   Mrs
# 4            5         0       3  35.0   NaN        S          24    Mr
#
#    IsMale  NumRelatives  FarePerPerson
# 0       1             1         7.2500
# 1       0             1        71.2833
# 2       0             0         7.9250
# 3       0             1        26.5500
# 4       1             0         8.0500

# %% [markdown]
# ##  Cabin

# %%
train['Cabin'].head(100).dropna()
# Out:
# 1             C85
# 3            C123
# 6             E46
# 10             G6
# 11           C103
# 21            D56
# 23             A6
# 27    C23 C25 C27
# 31            B78
# 52            D33
# 54            B30
# 55            C52
# 61            B28
# 62            C83
# 66            F33
# 75          F G73
# 88    C23 C25 C27
# 92            E31
# 96             A5
# 97        D10 D12
# Name: Cabin, dtype: object

# %%
def clean_cabin(x):
    
    letter=x[0]
    
    if letter not in 'ABCDEF':
        letter='F'
        
    return(letter)
    
train['Cabin']=train['Cabin'].map(lambda x: clean_cabin(x), na_action='ignore')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age Cabin Embarked  NameLength Title  \
# 0            1         0       3  22.0   NaN        S          23    Mr
# 1            2         1       1  38.0     C        C          51   Mrs
# 2            3         1       3  26.0   NaN        S          22  Miss
# 3            4         1       1  35.0     C        S          44   Mrs
# 4            5         0       3  35.0   NaN        S          24    Mr
#
#    IsMale  NumRelatives  FarePerPerson
# 0       1             1         7.2500
# 1       0             1        71.2833
# 2       0             0         7.9250
# 3       0             1        26.5500
# 4       1             0         8.0500

# %% [markdown]
# ## Embarked

# %%
# impute two missing with majority class
train['Embarked']=train['Embarked'].fillna('S')

# %%
# create dummies?

# %% [markdown]
# ## Age

# %%
len(train['Age'][train['Age'].isna()])
# Out:
# 177

# %%
# impute missing values

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass   Age Cabin Embarked  NameLength Title  \
# 0            1         0       3  22.0   NaN        S          23    Mr
# 1            2         1       1  38.0     C        C          51   Mrs
# 2            3         1       3  26.0   NaN        S          22  Miss
# 3            4         1       1  35.0     C        S          44   Mrs
# 4            5         0       3  35.0   NaN        S          24    Mr
#
#    IsMale  NumRelatives  FarePerPerson
# 0       1             1         7.2500
# 1       0             1        71.2833
# 2       0             0         7.9250
# 3       0             1        26.5500
# 4       1             0         8.0500

# %% [markdown]
# * Title: 3 dummies
# * Cabin: 5 dummies
# * Embarked: 2 dummies
# * Sex: 1 dummy
# * Pclass: 2 dummies
# * Age: numeric or 4 dummies

# %%
train['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Rare'], dtype=object)

# %%
# too many values to impute, use it only for tree model?
train['Cabin'].unique()
# Out:
# array([nan, 'C', 'E', 'F', 'D', 'A', 'B'], dtype=object)

# %%
len(train['Cabin'][train['Cabin'].isna()])
# Out:
# 687
